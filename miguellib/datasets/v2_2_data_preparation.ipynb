# %%
from v2_utils import load_csv, run_pipeline

df_products = load_csv("data/products_dataset_raw.csv")
df_prices = load_csv("data/prices_raw.csv")

df_processed = run_pipeline(df_products, df_prices)
df_processed.head()
# Out:
#                                         product_name           brand  \
# 0  No7 Hydra Luminous Aqua Release Skin Perfector...             No7
# 1  Tower 28 SOS Daily Rescue Facial Spray, 4 fl o...        Tower 28
# 2  Clinique Takes the Day Off Cleansing Oil, 6.7 ...        Clinique
# 3  Necessaire The Body Lotion, Fragrance Free, 15...      Necessaire
# 4  Paula’s Choice Resist Weightless Advanced Repa...  Paula'S Choice
#
#              usage_type              category  \
# 0                  Face   Tinted Moisturizers
# 1                  Face     Spray Moisturizer
# 2      Facial Cleansers  Facial Cleansing Oil
# 3                  Body               Lotions
# 4  Toners & Astringents                Toners
#
#                                          ingredients  \
# 0  propylene glycol, alcohol denat, anhydroxylito...
# 1          hypochlorous acid, sodium chloride, water
# 2  bht, caprylyl glycol, cetyl ethylhexanoate, gl...
# 3  aqua/water/eau, caprylhydroxamic acid, capryli...
# 4  acetyl glucosamine, adenosine, butylene glycol...
#
#                                            image_url  \
# 0  https://cdn1.skinsafeproducts.com/photo/E84797...
# 1  https://cdn1.skinsafeproducts.com/photo/488026...
# 2  https://cdn1.skinsafeproducts.com/photo/53EEB4...
# 3  https://cdn1.skinsafeproducts.com/photo/D9ADD5...
# 4  https://cdn1.skinsafeproducts.com/photo/2A9B12...
#
#                                          product_url  price
# 0  https://www.skinsafeproducts.com/no7-hydra-lum...  15.29
# 1  https://www.skinsafeproducts.com/tower-28-sos-...   5.48
# 2  https://www.skinsafeproducts.com/clinique-take...  43.95
# 3  https://www.skinsafeproducts.com/necessaire-th...  13.48
# 4  https://www.skinsafeproducts.com/paula-s-choic...  18.00

# %%
df_processed[['brand','product_name','price']].head()
# Out:
#             brand                                       product_name  price
# 0             No7  No7 Hydra Luminous Aqua Release Skin Perfector...  15.29
# 1        Tower 28  Tower 28 SOS Daily Rescue Facial Spray, 4 fl o...   5.48
# 2        Clinique  Clinique Takes the Day Off Cleansing Oil, 6.7 ...  43.95
# 3      Necessaire  Necessaire The Body Lotion, Fragrance Free, 15...  13.48
# 4  Paula'S Choice  Paula’s Choice Resist Weightless Advanced Repa...  18.00
